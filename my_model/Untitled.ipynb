# %%
import tensorflow as tf

# %%
# Replace 'your_model.tflite' with the path to your TFLite model file.
interpreter = tf.lite.Interpreter(model_path='converted_model.tflite')

try:
    interpreter.allocate_tensors()
    # If the model is loaded successfully, it should be compatible with the interpreter.
    # You can proceed with inference.
except Exception as e:
    # Handle any errors or exceptions here.
    # If you encounter compatibility issues, an exception may be raised.
    print("Model compatibility check failed:", e)

# %%
interpreter

# %%
model_metadata = interpreter.get_tensor_details()

# %%
model_metadata
# Out:
# [{'name': 'serving_default_input_1:0',
#   'index': 0,
#   'shape': array([  1,  36, 100, 100,   1]),
#   'shape_signature': array([ -1,  36, 100, 100,   1]),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'model/multi_head_attention/key/einsum/Einsum',
#   'index': 1,
#   'shape': array([128, 128]),
#   'shape_signature': array([128, 128]),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'model/multi_head_attention/query/einsum/Einsum',
#   'index': 2,
#   'shape': array([128, 128]),
#   'shape_signature': array([128, 128]),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
# ...

# %%
for entry in model_metadata:
    if 'tensorflow_version' in entry.get('name', ''):
        print(f'TFLite Version: {entry["buffer"]}')
